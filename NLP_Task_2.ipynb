# %% [markdown]
# <a href="https://colab.research.google.com/github/karanpk02/Task_8/blob/main/NLP_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Natural Language Processing Task**
# ##**Task-1**
#
# You need to translate each word or sentence from English to Spanish, French and German
#
# Data Set : https://drive.google.com/file/d/1YMHJjblc8dDzUN1ry8BOCnAR4_TyKmXM/view?usp=sharing
#
#
# ##**Task-2**
#
# Create a program that needs to automatically correct that spelling from the word or a given sentence. (Language : English)
# Note:  show 100 data point outputs both in words and sentence.
#
#
#
# ##**Task-3**
#
# Create an application that should be used by the HR Team to filter the resume based on the Skills.
#
#
# ##**Task-4**
# Create a chatbot for Hotel Management to Book Rooms
#
# ###**Details collected from :**
# Customer Name, Mobile Number, Address, ID proof, and Room Type and date of arrival and departure date. Keep some eligibility to Book the Room .
# All through voice to text classifications

# %% [markdown]
# #**Task_2**

# %%
import pandas as pd

# %%
df = pd.read_fwf('https://raw.githubusercontent.com/karanpk02/Task_8/main/sample.txt')
df
# Out:
#                2
# 0           1080
# 1             &c
# 2       10-point
# 3           10th
# 4       11-point
# ...          ...
# 466544    Zwolle
# 466545  Zworykin
# 466546        ZZ
# 466547       zZt
# 466548       ZZZ
#
# [466549 rows x 1 columns]

# %%
# df.to_csv('sample.txt', index=False)

# %%
df = df.sample(frac=0.001)

# %%
df.shape
# Out:
# (467, 1)

# %%
import nltk
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams

# %%
nltk.download('words')
from nltk.corpus import words
correct_words = words.words()
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
# df.values
df = df['2'].tolist()

# %%
df
# Out:
# ['frosk',
#  'Morcote',
#  'Raumur',
#  'polyphas',
#  'tidiose',
#  'jocatory',
#  'Delphina',
#  'Wykeham',
#  'applicat',
#  'heteroch',
#  'curdy',
#  'sermones',
#  'opopanax',
#  'streetwi',
#  'overread',
#  'miscondu',
#  'mistakio',
#  'mastoidi',
#  'Maas',
#  'parergic',
#  'disnatur',
#  'Basso',
#  'Malan',
#  'Iene',
#  'rootcap',
#  'borickit',
#  'terrestr',
#  'FFA',
#  'Mordecai',
#  'drip-dri',
#  'backscat',
#  'outreach',
#  'attentat',
#  'tritons',
#  'basenjis',
#  'profit-p',
#  'Acanthop',
#  'schemes',
#  'fishergi',
#  'siderate',
#  'gruffs',
#  'ichthyos',
#  'pottiest',
#  'Leund',
#  'rivalled',
#  'dehydrog',
#  'theologi',
#  'chytra',
#  'protonat',
#  'unvolati',
#  'windsock',
#  'electrob',
#  'bartend',
#  'plagose',
#  'silver-h',
#  'anthophi',
#  'constern',
#  'unpacifi',
#  'carinule',
#  'pro-ostr',
#  'assidual',
#  'fallowed',
#  'scleras',
#  'bromauri',
#  'equation',
#  'hypersex',
#  'Jarita',
#  'Bennion',
#  'cryptoge',
#  'ill-mate',
#  'Higganum',
#  'subcrani',
#  'advice',
#  'telesiur',
#  'spited',
#  'reforges',
#  'apothegm',
#  'open-air',
#  'begettin',
#  'semising',
#  'self-saf',
#  'surgical',
#  'Kasseri',
#  'Amphissu',
#  'onomatol',
#  'reddish-',
#  'gimlet',
#  'nonextri',
#  'well-off',
#  'calliper',
#  'slowbell',
#  'rose-tin',
#  'pre-Ammo',
#  'stodgine',
#  'diprotod',
#  'Deirdre',
#  'makeress',
#  'scale-up',
#  'tea-part',
#  'travel-s',
#  'leftment',
#  'sulphour',
#  'unharang',
#  'Gaffkya',
#  'adiaphon',
#  'paddle',
#  'question',
#  'tetrazon',
#  'lamper-e',
#  'overgrad',
#  'strobili',
#  'disable',
#  'self-hum',
#  'Grafen',
#  'electrob',
#  'Normanto',
#  'unleaf',
#  'venerabl',
#  'stoop',
#  'confeder',
#  'sulphald',
#  'pycnotic',
#  'lithontr',
#  'off-mike',
#  'both-han',
#  'demurest',
#  'patente',
#  'spurtive',
#  'phospho',
#  'Jobina',
#  'Desdamon',
#  'rewiring',
#  'nonabrid',
#  'ambagiou',
#  'disbranc',
#  'axiopist',
#  'sops',
#  'antherif',
#  'russud',
#  'beswink',
#  'function',
#  'peachier',
#  'brinks',
#  'portolan',
#  'anthopho',
#  'zaburro',
#  'Krauthea',
#  'gyn',
#  'assume',
#  'Geez',
#  'planchet',
#  'confisca',
#  'workmanl',
#  'yokemate',
#  'ephods',
#  'Deiphobu',
#  'mandarin',
#  'unpirati',
#  'Actinomy',
#  'chymous',
#  'nazim',
#  'shortwav',
#  'ombrophy',
#  'titular',
#  'mainmast',
#  'postarti',
#  'reassert',
#  "bat's",
#  'genomic',
#  'galvanic',
#  'outdream',
#  'poppy-cr',
#  'trinerve',
#  'drageoir',
#  'Wapisian',
#  'moonwalk',
#  'mirvs',
#  'geosynch',
#  'consonan',
#  'Bouckvil',
#  'Eilshemi',
#  'slingman',
#  'misappoi',
#  'preversi',
#  'bacterio',
#  'transpla',
#  'fakes',
#  'hr-',
#  'dog-watc',
#  'priest-r',
#  'ewound',
#  'tetrakai',
#  'baryons',
#  'nonhyper',
#  'uncus',
#  'subgenus',
#  'nonmulti',
#  'demifusi',
#  'trade-un',
#  'updrag',
#  'pleurotr',
#  'alimenta',
#  'Buderus',
#  'loquacio',
#  'impleasi',
#  'cheilost',
#  'polyspor',
#  'piney',
#  'sesquipe',
#  'Cryptoph',
#  'pseudoem',
#  'loriot',
#  'queazies',
#  'corniche',
#  'Ronan',
#  'semicolo',
#  'cannel-b',
#  'corelati',
#  'upo',
#  'galactem',
#  'Fenelon',
#  'quasi-co',
#  'begluc',
#  'gutsier',
#  'elderbus',
#  'saults',
#  'canful',
#  'appariti',
#  'prises',
#  'white-ac',
#  'circumlo',
#  'stenos',
#  'Heisenbe',
#  'noll-kho',
#  'Chromoba',
#  'squinanc',
#  'lactifie',
#  'Gascogne',
#  'mulefoot',
#  'adstipul',
#  'cystidic',
#  'air-chee',
#  'carfax',
#  'unlatch',
#  'ashfall',
#  'loots',
#  'develope',
#  'auriflam',
#  'lifemans',
#  'nonrever',
#  'mesquite',
#  'acupunct',
#  'naplessn',
#  'serac',
#  'reddlema',
#  'reconfus',
#  'Lemmueu',
#  'beatniki',
#  'cross-la',
#  'casehard',
#  'tubercul',
#  'bitch',
#  'mewer',
#  'nonabsor',
#  'clomben',
#  'wind-gra',
#  'primal',
#  'goatston',
#  'Ampyx',
#  'enkindle',
#  'bloodthi',
#  'hectogra',
#  'dustee',
#  'splotchi',
#  'welldoer',
#  'mustier',
#  'PPA',
#  'burrier',
#  'Chtaura',
#  'BBXRT',
#  'large-ey',
#  'recupera',
#  'pseudony',
#  'Fitzclar',
#  'along',
#  'gluing',
#  'ploughsh',
#  'refutabl',
#  'successi',
#  'antemort',
#  'institut',
#  'divinity',
#  'protext',
#  'semihype',
#  'Nukuhiva',
#  'steganog',
#  'wristdro',
#  'straboto',
#  'dicoccou',
#  'rubasses',
#  'bibliopo',
#  'overcomm',
#  'greatcoa',
#  'deep-dam',
#  "two's",
#  'karabine',
#  'subsyste',
#  'cocullo',
#  'prophloe',
#  'Norrkopi',
#  'Dasyproc',
#  'contouri',
#  'Teiidae',
#  'misappre',
#  'multiton',
#  'chemotro',
#  'rectoria',
#  'prefator',
#  'chlordan',
#  'antifema',
#  'paraglob',
#  'Nebraska',
#  'glueynes',
#  'affixtur',
#  'verbaliz',
#  'Lyaeus',
#  'bianisid',
#  'Danaus',
#  'chrysori',
#  'Pro-anna',
#  'refutati',
#  'Baxley',
#  'bullaria',
#  'Auduboni',
#  'multipar',
#  'misdrive',
#  'amber-lo',
#  'nontacti',
#  'incontes',
#  'sciagrap',
#  'veinston',
#  'vestibul',
#  'catameni',
#  'podsolic',
#  'papillat',
#  'bewrayin',
#  'redempto',
#  'nostalgi',
#  'creosoti',
#  'Russel',
#  'Deadwood',
#  'evangeli',
#  'universa',
#  'Amsterda',
#  'CSU',
#  'chitinog',
#  'pediadon',
#  'loranski',
#  'hackle',
#  'overscou',
#  'blockade',
#  'triguttu',
#  'Raynham',
#  'swallowt',
#  'nonparti',
#  'Gerbold',
#  'amphibra',
#  'unscabro',
#  'synesis',
#  'sprightf',
#  'nippers',
#  'recubant',
#  'gawby',
#  'limoid',
#  'cisium',
#  'enricher',
#  'sandfish',
#  'reenclos',
#  'Villamar',
#  'hommocks',
#  'nonaccum',
#  'meas',
#  'apiarari',
#  'angelica',
#  'hydrocar',
#  'phenomen',
#  'arithmoc',
#  'uninfect',
#  'hierarch',
#  'Hillcres',
#  'like-per',
#  'heaven-w',
#  'Aix-en-P',
#  'orderedn',
#  'Strathcl',
#  'overfatt',
#  'uneaten',
#  'bechamel',
#  'nonconst',
#  'vexilla',
#  'self-sca',
#  'intitled',
#  'subcaeca',
#  'Isolda',
#  'hogties',
#  'nonannih',
#  'nonpesti',
#  'interfer',
#  'unpostma',
#  'Sevik',
#  'reverber',
#  'pensee',
#  'horse-na',
#  'catholic',
#  'summerhe',
#  'countert',
#  'undergos',
#  'nonperpe',
#  'sliping',
#  'stearopt',
#  'amblyope',
#  'scintill',
#  'nonprosp',
#  'uxoricid',
#  'gassing',
#  'aminoace',
#  'compaa',
#  'tintack',
#  'niacins',
#  'reified',
#  'gimmerpe',
#  'whole-se',
#  'vingtiem',
#  'baptisms',
#  'physopod',
#  'sterilan',
#  'verminer',
#  'tough-li',
#  'wolfward',
#  'Polypodi',
#  'songstre',
#  'unservic',
#  'loquacit',
#  'coltishn',
#  'semideif',
#  'uninhabi',
#  'coassist',
#  'sextuply',
#  'felicito',
#  'Grewitz',
#  "bagpipe'",
#  'unsuppor',
#  'prerailw',
#  'catogeni',
#  'artichok',
#  'ultracen',
#  'kabbala',
#  'calvous',
#  'autotetr',
#  'iconolat',
#  'scholast',
#  'mesteso',
#  'unbalanc',
#  'Bellina',
#  'stele',
#  'epinasty',
#  'invultua']

# %%
# list of incorrect spellings
# that need to be corrected 

df1=[]
incorrect_words=['happpy', 'azmaing', 'intelliengt']  
# loop for finding correct spellings
# based on jaccard distance
# and printing the correct word
for word in incorrect_words:
    temp = [(jaccard_distance(set(ngrams(word, 2)),
                              set(ngrams(w, 2))),w)
            for w in correct_words if w[0]==word[0]]
    df1.append(sorted(temp, key = lambda val:val[0])[0][1])        
df1
# Out:
# ['happy', 'amazing', 'intelligent']

# %%
df1=[]
for word in df:
    temp = [(jaccard_distance(set(ngrams(word, 2)),
                              set(ngrams(w, 2))),w)
            for w in correct_words if w[0]==word[0]]
    df1.append(sorted(temp, key = lambda val:val[0])[0][1])        
df1
# Out:
# ['frosh',
#  'Morcote',
#  'Rauraci',
#  'polyphase',
#  'tidily',
#  'joculator',
#  'Delphin',
#  'Wykehamist',
#  'applicate',
#  'hetero',
#  'curdy',
#  'sermoner',
#  'opopanax',
#  'streetwise',
#  'overread',
#  'misconduct',
#  'mistaking',
#  'mastoid',
#  'Mass',
#  'parergic',
#  'disnature',
#  'Bassa',
#  'Malayan',
#  'Ierne',
#  'rootcap',
#  'borickite',
#  'terrestrial',
#  'F',
#  'Mordella',
#  'drip',
#  'baccate',
#  'outreach',
#  'attent',
#  'triton',
#  'basenji',
#  'profit',
#  'Acanthopanax',
#  'scheme',
#  'fishergirl',
#  'sideral',
#  'gruffs',
#  'ichthyosis',
#  'potting',
#  'Leung',
#  'rivalless',
#  'dehydrogenase',
#  'theologi',
#  'chytra',
#  'pronator',
#  'unvolatile',
#  'windshock',
#  'electro',
#  'bartender',
#  'plagose',
#  'silver',
#  'anthophile',
#  'consternate',
#  'unpacific',
#  'carina',
#  'prostrate',
#  'assidual',
#  'fallow',
#  'sclera',
#  'bromauric',
#  'equation',
#  'hyper',
#  'Jabarite',
#  'Beni',
#  'cryptogenic',
#  'illutate',
#  'Hemiganus',
#  'subcranial',
#  'advice',
#  'telesia',
#  'spitted',
#  'reforge',
#  'apothegm',
#  'open',
#  'betinge',
#  'semisingle',
#  'self',
#  'surgical',
#  'Kamass',
#  'Amphisile',
#  'onomatology',
#  'reddish',
#  'gimlet',
#  'nonextrinsic',
#  'well',
#  'calliper',
#  'slowbelly',
#  'roseine',
#  'premold',
#  'stodginess',
#  'diprotodont',
#  'Deirdre',
#  'makeress',
#  'scale',
#  'teart',
#  'travel',
#  'leftments',
#  'sulphourea',
#  'unhang',
#  'Gaffkya',
#  'adiaphon',
#  'paddle',
#  'question',
#  'tetrazone',
#  'lamper',
#  'overgrade',
#  'strobili',
#  'disable',
#  'self',
#  'Graafian',
#  'electro',
#  'Norman',
#  'unleaf',
#  'venerable',
#  'stoop',
#  'confederal',
#  'sulpha',
#  'pycnotic',
#  'lithontriptic',
#  'offtake',
#  'both',
#  'demure',
#  'patent',
#  'spurtive',
#  'phospho',
#  'Job',
#  'Damon',
#  'rewin',
#  'nonabridgment',
#  'ambagious',
#  'disbranch',
#  'axiopisty',
#  'sop',
#  'antherid',
#  'russud',
#  'beeswing',
#  'function',
#  'peacher',
#  'brink',
#  'portolan',
#  'anthophore',
#  'zeburro',
#  'Kra',
#  'gyn',
#  'assume',
#  'Geez',
#  'planchet',
#  'confiscate',
#  'workmanly',
#  'yokemate',
#  'ephod',
#  'Deiphobus',
#  'mandarin',
#  'unpirated',
#  'Actinomyces',
#  'chymous',
#  'nazim',
#  'short',
#  'ombrophyte',
#  'titular',
#  'mainmast',
#  'postarticular',
#  'reassert',
#  'bat',
#  'genomic',
#  'galvanic',
#  'outdream',
#  'poppy',
#  'trinerve',
#  'dragged',
#  'Wapisiana',
#  'moonwalker',
#  'mir',
#  'geosyncline',
#  'consonant',
#  'Bougainvillea',
#  'Euphemia',
#  'slingsman',
#  'misappoint',
#  'preversion',
#  'bacterioid',
#  'transplant',
#  'fake',
#  'highroad',
#  'dogwatch',
#  'priest',
#  'enwound',
#  'tetra',
#  'baronry',
#  'nonhero',
#  'uncus',
#  'subgenus',
#  'nonmultiple',
#  'demifusion',
#  'trade',
#  'updrag',
#  'pleurotribe',
#  'alimental',
#  'Bud',
#  'loquacious',
#  'implead',
#  'cheilostomatous',
#  'polyspore',
#  'piney',
#  'sesqui',
#  'Cryptophyceae',
#  'pseudo',
#  'loriot',
#  'queak',
#  'cornic',
#  'Ron',
#  'semicolon',
#  'cannel',
#  'correlation',
#  'upo',
#  'galactemia',
#  'Felapton',
#  'quasi',
#  'begluc',
#  'gussie',
#  'elderbush',
#  'sault',
#  'canful',
#  'apparition',
#  'presurprise',
#  'white',
#  'circumlocute',
#  'steno',
#  'Heavenese',
#  'noll',
#  'Chrobat',
#  'squinance',
#  'lactific',
#  'Gascon',
#  'mulefoot',
#  'adstipulate',
#  'cystic',
#  'airhead',
#  'carfax',
#  'unlatch',
#  'all',
#  'loot',
#  'developer',
#  'aurify',
#  'liftman',
#  'nonreverse',
#  'mesquite',
#  'acupuncture',
#  'naplessness',
#  'sera',
#  'reddleman',
#  'reconfuse',
#  'Lemmus',
#  'beat',
#  'cross',
#  'caseharden',
#  'tubercula',
#  'bitch',
#  'mewer',
#  'nonabsorbable',
#  'clomben',
#  'wind',
#  'primal',
#  'goatstone',
#  'Ampelis',
#  'enkindle',
#  'bloodthirst',
#  'hectogram',
#  'dustee',
#  'splotch',
#  'welder',
#  'muster',
#  'P',
#  'burier',
#  'Chamaesaura',
#  'B',
#  'large',
#  'recuperate',
#  'pseudonym',
#  'Fitzclarence',
#  'along',
#  'glutting',
#  'plough',
#  'refutable',
#  'success',
#  'antemortal',
#  'institute',
#  'divinity',
#  'protext',
#  'semihyperbola',
#  'Nukuhivan',
#  'steganogram',
#  'wrist',
#  'strabotome',
#  'dicoccous',
#  'rubasse',
#  'bibliopole',
#  'overcommon',
#  'greatcoat',
#  'deep',
#  'two',
#  'karaka',
#  'subsystem',
#  'cocullo',
#  'prophloem',
#  'Norroy',
#  'Dasyprocta',
#  'contour',
#  'Teiidae',
#  'misapprehend',
#  'multitoned',
#  'chemotropic',
#  'rectorial',
#  'prefator',
#  'chlordan',
#  'antifelon',
#  'paraglobin',
#  'Nebraskan',
#  'glueyness',
#  'affixture',
#  'verbalize',
#  'Lenaeus',
#  'bianisidine',
#  'Dana',
#  'chrysorin',
#  'Panna',
#  'refutation',
#  'Barney',
#  'bullary',
#  'Audubonistic',
#  'multipara',
#  'misdrive',
#  'amber',
#  'nontactical',
#  'incontestable',
#  'sciograph',
#  'veinstone',
#  'vestibula',
#  'catamenia',
#  'podsolic',
#  'papillate',
#  'bewray',
#  'redemptor',
#  'nostalgia',
#  'creosotic',
#  'Russell',
#  'Dean',
#  'evangelian',
#  'universal',
#  'Amsterdamer',
#  'C',
#  'chitin',
#  'pediadontia',
#  'loranskite',
#  'hackle',
#  'overscour',
#  'blockade',
#  'triguttulate',
#  'Ram',
#  'swallow',
#  'nonpartial',
#  'Gerald',
#  'amphibrach',
#  'unscabbed',
#  'synesis',
#  'sprightful',
#  'nippers',
#  'recubant',
#  'gawby',
#  'limoid',
#  'cesium',
#  'enricher',
#  'sandfish',
#  'reclose',
#  'Villanova',
#  'hammock',
#  'nonacute',
#  'mease',
#  'apiarian',
#  'angelica',
#  'hydrocarbon',
#  'phenomena',
#  'arithmocracy',
#  'uninfected',
#  'hierarch',
#  'Hillel',
#  'liker',
#  'heaven',
#  'Aix',
#  'ordered',
#  'Strad',
#  'overfat',
#  'uneaten',
#  'bechalk',
#  'noncon',
#  'vexillar',
#  'scasely',
#  'intitule',
#  'subcaecal',
#  'Isolde',
#  'hoggie',
#  'nonnant',
#  'nonpedestrian',
#  'interfere',
#  'unpostmarked',
#  'Sevillian',
#  'reverb',
#  'peen',
#  'horse',
#  'catholic',
#  'summerhead',
#  'counterterm',
#  'undergo',
#  'nonperson',
#  'slipping',
#  'stearoptene',
#  'amblyope',
#  'scintilla',
#  'nonprospect',
#  'uxoricide',
#  'gassing',
#  'aminoacetal',
#  'compact',
#  'tinta',
#  'niacin',
#  'rectified',
#  'gimmerpet',
#  'whole',
#  'vierling',
#  'baptism',
#  'physopod',
#  'sterile',
#  'verminer',
#  'tough',
#  'wolfward',
#  'Polypodium',
#  'songstress',
#  'unservile',
#  'loquacity',
#  'coltish',
#  'semideific',
#  'uninhabited',
#  'coassist',
#  'sextuply',
#  'felicitous',
#  'Grewia',
#  'bagpipe',
#  'unsupported',
#  'prerailway',
#  'catogenic',
#  'artichoke',
#  'ultra',
#  'kala',
#  'calvous',
#  'autotetraploid',
#  'iconolater',
#  'scholastic',
#  'mestee',
#  'unbalance',
#  'Bellis',
#  'stele',
#  'epinasty',
#  'invultuation']

# %%
df = pd.DataFrame({'Actual': df, 'Corrected': df1})
df
# Out:
#        Actual     Corrected
# 0       frosk         frosh
# 1     Morcote       Morcote
# 2      Raumur       Rauraci
# 3    polyphas     polyphase
# 4     tidiose        tidily
# ..        ...           ...
# 462  unbalanc     unbalance
# 463   Bellina        Bellis
# 464     stele         stele
# 465  epinasty      epinasty
# 466  invultua  invultuation
#
# [467 rows x 2 columns]
